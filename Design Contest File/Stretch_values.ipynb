# %%
import matplotlib
from datascience import *
# %matplotlib inline
import matplotlib.pyplot as plots
import numpy as np
import pandas as pd
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from matplotlib import pyplot as plt
import seaborn as sns

import graphviz
import pydotplus
import io
from scipy import misc
from sklearn.tree import export_graphviz
# %matplotlib inline
plots.style.use('fivethirtyeight')

# %%
data = Table.read_table('C:/Users/burakalbayrak/Desktop/HARdata/stretch_data_22_users_with_window.csv')

# %%
data
x=data.group('Window Number')

# %%
x.column('count')
# Out:
# array([17831, 16899, 15976, 14763, 14495, 13965, 14179, 13747, 12940,
#        13035, 13339, 12592, 12807, 13691, 13550, 14785, 15154, 14170,
#        14690, 14223, 14486, 14069, 13314, 13323, 13043, 12495, 12035,
#        11140, 10764,  9597,  9368,  8811,  9447,  9198,  9375,  8764,
#         8652,  7623,  7492,  7110,  6316,  5584,  5515,  4785,  4163,
#         3786,  3678,  2859,  2811,  3139,  2732,  2482,  2164,  2267,
#         1964,  1932,  1800,  1781,  1750,  1483,  1330,  1439,  1434,
#         1458,  1485,  1426,  1274,  1305,  1190,  1463,  1396,  1439,
#         1420,  1529,  1449,  1273,  1366,  1086,  1036,  1071,   883,
#         1043,  1047,   982,   945,   911,  1058,  1076,  1093,  1017,
#         1034,   700,   838,  1022,  1019,  1019,   884,  1033,  1021,
#          736,   842,   750,   903,   873,   922,   781,  1030,   627,
#          771,   878,   595,   595,   594,   598,   522,   437,   442,
# ...

# %%
#data.where('Window Number',1).sort('Stretch Value', descending=True)
Total_stretch_at_each_window=data.group('Window Number',sum).column('Stretch Value sum')

# %%
data.group('Window Number').with_column('Total Stretch',Total_stretch_at_each_window)
# Out:
# Window Number | count | Total Stretch
# 1             | 17831 | 7.49377e+06
# 2             | 16899 | 7.09524e+06
# 3             | 15976 | 6.73494e+06
# 4             | 14763 | 6.22072e+06
# 5             | 14495 | 6.10281e+06
# 6             | 13965 | 5.9279e+06
# 7             | 14179 | 6.01012e+06
# 8             | 13747 | 5.85308e+06
# 9             | 12940 | 5.54765e+06
# 10            | 13035 | 5.59298e+06
# ... (203 rows omitted)

# %%
user_1=data.where('User',1)
user_1
user2=data.where('User',2)

# %%
#np.average(user_1.column('Stretch Value'))
user1_avg=user_1.group('Window Number',np.average)
user1_avg
user2_avg=user2.group('Window Number',np.average)

# %%
user2_avg.plot('Window Number', 'Stretch Value average')

# %%
user1_avg.plot('Window Number', 'Stretch Value average')
